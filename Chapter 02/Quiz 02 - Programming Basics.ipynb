# %% [markdown]
# <a href="https://colab.research.google.com/github/HandsOnPythonProgramming/Hands-On-Python-Programming/blob/main/Chapter%2002/Quiz%2002%20-%20Programming%20Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="width:100%; display:flex; justify-content:space-between; align-items:center;">
#   <h1 style="margin:0;">Quiz 02</h1>
#   <img src="https://github.com/HandsOnPythonProgramming/Hands-On-Python-Programming/blob/main/Images/book_logo.jpg?raw=true" width="40"/>
# </div>
#
# ---
#
# Programming Basics

# %%
# @title Start Quiz

from google.colab import drive
drive.mount('/content/drive')

import sys, io, contextlib

# Add your python_data folder to Python path
sys.path.append("https://raw.githubusercontent.com/HandsOnPythonProgramming/Hands-On-Python-Programming/main/Data/quiz_data/python_data")

# Silent launcher (hides all Gradio/Colab text)
def silent_launch(app):
    buffer = io.StringIO()
    with contextlib.redirect_stdout(buffer):
        app.launch(share=False, inline=True, debug=False, show_error=False)

# Import the quiz module
from quiz_02 import demo

# Launch the quiz
silent_launch(demo)
