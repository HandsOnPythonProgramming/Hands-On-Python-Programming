# %% [markdown]
# <a href="https://colab.research.google.com/github/HandsOnPythonProgramming/Hands-On-Python-Programming/blob/main/Chapter%2003/Quiz%2003%20-%20Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="width:100%; display:flex; justify-content:space-between; align-items:center;">
#   <h1 style="margin:0;">Quiz 03</h1>
#   <img src="https://github.com/HandsOnPythonProgramming/Hands-On-Python-Programming/blob/main/Images/book_logo.jpg?raw=true" width="40"/>
# </div>
#
# ---
#
# Operators

# %%
# @title Start Quiz

from google.colab import drive
drive.mount('/content/drive')

import requests
import io
import contextlib

# Direct link to raw quiz file on GitHub
url = "https://raw.githubusercontent.com/HandsOnPythonProgramming/Hands-On-Python-Programming/main/Data/quiz_data/python_data"

open("quiz_03.py", "w").write(requests.get(url).text)

# Silent launcher
def silent_launch(app):
    buffer = io.StringIO()

    with contextlib.redirect_stdout(buffer):
        app.launch(
            share=False,
            inline=True,
            debug=False,
            show_error=False
        )

# Import quiz
from quiz_03 import demo

# Launch
silent_launch(demo)
