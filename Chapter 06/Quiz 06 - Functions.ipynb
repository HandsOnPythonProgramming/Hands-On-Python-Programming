# %% [markdown]
# <a href="https://colab.research.google.com/github/HandsOnPythonProgramming/Hands-On-Python-Programming/blob/main/Chapter%2006/Quiz%2006%20-%20Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="width:100%; display:flex; justify-content:space-between; align-items:center;">
#   <h1 style="margin:0;">Quiz 06</h1>
#   <img src="https://github.com/HandsOnPythonProgramming/Hands-On-Python-Programming/blob/main/Images/book_logo.jpg?raw=true" width="40"/>
# </div>
#
# ---
# Functions

# %%
# @title Start Quiz

import sys, io, contextlib, importlib, os

# Silent launcher
def silent_launch(app):
    buffer = io.StringIO()
    with contextlib.redirect_stdout(buffer):
        app.launch(share=False, inline=True, debug=False, show_error=False)

# Download the updated Python quiz file
# !wget -q https://raw.githubusercontent.com/HandsOnPythonProgramming/Hands-On-Python-Programming/main/Data/quiz_data/python_data/quiz_06.py

# Load the module
import importlib
import quiz_06
importlib.reload(quiz_06)

# Launch the quiz
silent_launch(quiz_06.demo)
