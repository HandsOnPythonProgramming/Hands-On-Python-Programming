# %% [markdown]
# <a href="https://colab.research.google.com/github/HandsOnPythonProgramming/Hands-On-Python-Programming/blob/main/Quiz/Quiz%2005%20-%20Control%20Flow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Quiz 5
#
# ---
# Control Flow

# %%
# @title Start Quiz

from google.colab import drive
drive.mount('/content/drive')

import sys, io, contextlib

# Add your python_data folder to Python path
sys.path.append('/content/drive/MyDrive/quiz_data/python_data')

# Silent launcher (hides all Gradio/Colab text)
def silent_launch(app):
    buffer = io.StringIO()
    with contextlib.redirect_stdout(buffer):
        app.launch(share=False, inline=True, debug=False, show_error=False)

# Import the quiz module
from quiz_5 import demo

# Launch the quiz
silent_launch(demo)
